# %%
from bs4 import BeautifulSoup as bs

# %%
soup = bs(file,'html.parser')

# %%
a = soup.findAll("td", {"class": "s3"})
s = {"hello"}
l = []
for i in a:
    
    s.add(i.get_text())
len(s),s
# Out:
# (156,
#  {'A Samad',
#   'Aashu Gupta',
#   'Aayush Jham',
#   'Abhigyan',
#   'Abhinav Anand',
#   'Abhineet',
#   'Abhishek Singh',
#   'Adarsh Tirkey',
#   'Aditi',
#   'Akshansh',
#   'Allam Bharath Reddy',
#   'Aman Ahlawat',
#   'Aman Gupta',
#   'Anand Vir Singh Chauhan',
#   'Ananya Gupta',
#   'Aniket Kathil',
#   'Aniket Kathil (International)',
#   'Animesh Pathak',
#   'Animesh Sah',
#   'Ankit Kumar',
#   'Anmol Agarwal',
#   'Anubhav Anand',
#   'Anuj Agarwal',
#   'Anurag Tyagi',
#   'Apoorv Kumar',
#   'Apoorva Nagar',
#   'Arjun Mehra',
#   'Arpit Gupta',
#   'Astha Sharan',
#   'Avi Chawla',
#   'Avnish Singh',
#   'Ayush Chakraborty',
#   'Ayush Goyal',
#   'Ayush Sharma',
#   'Ayushi Sneha',
#   'Bharat Jain',
#   'Bharat Reddy ',
#   'Bhavy Jain',
#   'Chaitanya Bhatia',
#   'Chandan Srivastava',
#   'Chander Shekher Pandey',
#   'Deepak Kumar Gour',
#   'Deepankar Vasant Umare',
#   'Deepanshu Vijay',
#   'Deepti Dewangan',
#   'Devank Rastogi',
# ...
